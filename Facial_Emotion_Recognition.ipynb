# %% [markdown]
# # Facial Emotion Recogination Using CNN Final Year Project

# %% [markdown]
# ## importing libraries

# %%
import numpy as np
import pandas as pd
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from keras.layers import Conv2D, Dense, BatchNormalization, Activation, Dropout, MaxPooling2D, Flatten
from keras.optimizers import Adam, RMSprop, SGD
from keras import regularizers
from keras.callbacks import ModelCheckpoint, CSVLogger, TensorBoard, EarlyStopping, ReduceLROnPlateau
import datetime
import matplotlib.pyplot as plt
from keras.utils import plot_model

# %% [markdown]
# ## Importing Dataset

# %%
train_dir = 'FER 2013/train/'
test_dir = 'FER 2013/test/'

row, col = 48, 48
classes = 7

def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = path + expression
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df
train_count = count_exp(train_dir, 'train')
test_count = count_exp(test_dir, 'test')
print(train_count)
print(test_count)
# Out:
#        angry  disgust  fear  happy  neutral   sad  surprise
# train   3995      436  4097   7215     4965  4830      3171
#       angry  disgust  fear  happy  neutral   sad  surprise
# test    958      111  1024   1774     1233  1247       831

# %% [markdown]
# ### PLot of number of images in training set

# %%
train_count.transpose().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ### PLot of number of images in test set

# %%
test_count.transpose().plot(kind='bar')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(14,22))
i = 1
for expression in os.listdir(train_dir):
    img = load_img((train_dir + expression +'/'+ os.listdir(train_dir + expression)[1]))
    plt.subplot(1,7,i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()

# %% [markdown]
# ## Creating Training and test sets

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   zoom_range=0.3,
                                   horizontal_flip=True)

training_set = train_datagen.flow_from_directory(train_dir,
                                                batch_size=64,
                                                target_size=(48,48),
                                                shuffle=True,
                                                color_mode='grayscale',
                                                class_mode='categorical')

test_datagen = ImageDataGenerator(rescale=1./255)
test_set = test_datagen.flow_from_directory(test_dir,
                                                batch_size=64,
                                                target_size=(48,48),
                                                shuffle=True,
                                                color_mode='grayscale',
                                                class_mode='categorical')
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
training_set.class_indices
# Out:
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %% [markdown]
# ## Defining Model

# %%
def get_model(input_size, classes=7):
     #Initialising the CNN
    model = tf.keras.models.Sequential()   

    model.add(Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu', input_shape =input_size))
    model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(2, 2))
    model.add(Dropout(0.25))

    model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(0.01)))
    model.add(Conv2D(256, kernel_size=(3, 3), activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(1024, activation='relu'))
    model.add(Dropout(0.5))
    
    model.add(Dense(classes, activation='softmax'))

    #Compliling the model
    model.compile(optimizer=Adam(lr=0.0001, decay=1e-6), 
                  loss='categorical_crossentropy', 
                  metrics=['accuracy'])
    return model

# %%
fernet = get_model((row,col,1), classes)
fernet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 64)        18496
#
#  batch_normalization (BatchN  (None, 48, 48, 64)       256
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 24, 24, 64)       0
#  )
#
#  dropout (Dropout)           (None, 24, 24, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 24, 24, 128)       73856
#
#  conv2d_3 (Conv2D)           (None, 22, 22, 256)       295168
#
#  batch_normalization_1 (Batc  (None, 22, 22, 256)      1024
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 11, 11, 256)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 11, 11, 256)       0
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 1024)              31720448
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 7)                 7175
#
# =================================================================
# Total params: 32,116,743
# Trainable params: 32,116,103
# Non-trainable params: 640
# _________________________________________________________________
# C:\Users\mailt\anaconda3\envs\tf\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
plot_model(fernet, to_file='fernet.png', show_shapes=True, show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# ### Callbacks Function

# %%
chk_path = 'ferNetModel.h5'
log_dir = "checkpoint/logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

checkpoint = ModelCheckpoint(filepath=chk_path,
                             save_best_only=True,
                             verbose=1,
                             mode='min',
                             moniter='val_loss')

earlystop = EarlyStopping(monitor='val_loss', 
                          min_delta=0, 
                          patience=3, 
                          verbose=1, 
                          restore_best_weights=True)
                        
reduce_lr = ReduceLROnPlateau(monitor='val_loss', 
                              factor=0.2, 
                              patience=6, 
                              verbose=1, 
                              min_delta=0.0001)


tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
csv_logger = CSVLogger('training.log')

callbacks = [checkpoint, reduce_lr, csv_logger]

# %% [markdown]
# ## Training Model

# %%
steps_per_epoch = training_set.n // training_set.batch_size
validation_steps = test_set.n // test_set.batch_size

hist = fernet.fit(x=training_set,
                 validation_data=test_set,
                 epochs=60,
                 callbacks=callbacks,
                 steps_per_epoch=steps_per_epoch,
                 validation_steps=validation_steps)
# Out:
# Epoch 1/60
# 448/448 [==============================] - ETA: 0s - loss: 4.2987 - accuracy: 0.2635
# Epoch 1: val_loss improved from inf to 4.91836, saving model to ferNet.h5
# 448/448 [==============================] - 71s 140ms/step - loss: 4.2987 - accuracy: 0.2635 - val_loss: 4.9184 - val_accuracy: 0.3302 - lr: 1.0000e-04
# Epoch 2/60
# 448/448 [==============================] - ETA: 0s - loss: 3.4841 - accuracy: 0.3205
# Epoch 2: val_loss improved from 4.91836 to 3.10825, saving model to ferNet.h5
# 448/448 [==============================] - 45s 100ms/step - loss: 3.4841 - accuracy: 0.3205 - val_loss: 3.1082 - val_accuracy: 0.3909 - lr: 1.0000e-04
# Epoch 3/60
# 448/448 [==============================] - ETA: 0s - loss: 2.9527 - accuracy: 0.3641
# Epoch 3: val_loss improved from 3.10825 to 2.62016, saving model to ferNet.h5
# 448/448 [==============================] - 43s 95ms/step - loss: 2.9527 - accuracy: 0.3641 - val_loss: 2.6202 - val_accuracy: 0.4315 - lr: 1.0000e-04
# Epoch 4/60
# 448/448 [==============================] - ETA: 0s - loss: 2.5443 - accuracy: 0.3899
# Epoch 4: val_loss improved from 2.62016 to 2.25840, saving model to ferNet.h5
# 448/448 [==============================] - 42s 94ms/step - loss: 2.5443 - accuracy: 0.3899 - val_loss: 2.2584 - val_accuracy: 0.4480 - lr: 1.0000e-04
# Epoch 5/60
# 448/448 [==============================] - ETA: 0s - loss: 2.2442 - accuracy: 0.4124
# Epoch 5: val_loss improved from 2.25840 to 1.99392, saving model to ferNet.h5
# 448/448 [==============================] - 43s 96ms/step - loss: 2.2442 - accuracy: 0.4124 - val_loss: 1.9939 - val_accuracy: 0.4660 - lr: 1.0000e-04
# Epoch 6/60
# 448/448 [==============================] - ETA: 0s - loss: 2.0063 - accuracy: 0.4359
# Epoch 6: val_loss improved from 1.99392 to 1.77936, saving model to ferNet.h5
# 448/448 [==============================] - 42s 94ms/step - loss: 2.0063 - accuracy: 0.4359 - val_loss: 1.7794 - val_accuracy: 0.4920 - lr: 1.0000e-04
# Epoch 7/60
# 448/448 [==============================] - ETA: 0s - loss: 1.8243 - accuracy: 0.4578
# Epoch 7: val_loss improved from 1.77936 to 1.63907, saving model to ferNet.h5
# 448/448 [==============================] - 42s 94ms/step - loss: 1.8243 - accuracy: 0.4578 - val_loss: 1.6391 - val_accuracy: 0.5077 - lr: 1.0000e-04
# Epoch 8/60
# 447/448 [============================>.] - ETA: 6s - loss: 1.6823 - accuracy: 0.4775
# Epoch 8: val_loss improved from 1.63907 to 1.52015, saving model to ferNet.h5
# 448/448 [==============================] - 2811s 6s/step - loss: 1.6819 - accuracy: 0.4775 - val_loss: 1.5201 - val_accuracy: 0.5218 - lr: 1.0000e-04
# Epoch 9/60
# 448/448 [==============================] - ETA: 0s - loss: 1.5755 - accuracy: 0.4940
# Epoch 9: val_loss improved from 1.52015 to 1.47507, saving model to ferNet.h5
# 448/448 [==============================] - 43s 97ms/step - loss: 1.5755 - accuracy: 0.4940 - val_loss: 1.4751 - val_accuracy: 0.5148 - lr: 1.0000e-04
# Epoch 10/60
# 448/448 [==============================] - ETA: 0s - loss: 1.4878 - accuracy: 0.5100
# Epoch 10: val_loss improved from 1.47507 to 1.38580, saving model to ferNet.h5
# 448/448 [==============================] - 42s 94ms/step - loss: 1.4878 - accuracy: 0.5100 - val_loss: 1.3858 - val_accuracy: 0.5423 - lr: 1.0000e-04
# Epoch 11/60
# 448/448 [==============================] - ETA: 0s - loss: 1.4194 - accuracy: 0.5256
# Epoch 11: val_loss improved from 1.38580 to 1.31102, saving model to ferNet.h5
# 448/448 [==============================] - 42s 94ms/step - loss: 1.4194 - accuracy: 0.5256 - val_loss: 1.3110 - val_accuracy: 0.5569 - lr: 1.0000e-04
# Epoch 12/60
# 448/448 [==============================] - ETA: 0s - loss: 1.3597 - accuracy: 0.5405
# Epoch 12: val_loss improved from 1.31102 to 1.27175, saving model to ferNet.h5
# 448/448 [==============================] - 42s 94ms/step - loss: 1.3597 - accuracy: 0.5405 - val_loss: 1.2717 - val_accuracy: 0.5699 - lr: 1.0000e-04
# Epoch 13/60
# 448/448 [==============================] - ETA: 0s - loss: 1.3085 - accuracy: 0.5531
# Epoch 13: val_loss improved from 1.27175 to 1.24087, saving model to ferNet.h5
# 448/448 [==============================] - 43s 96ms/step - loss: 1.3085 - accuracy: 0.5531 - val_loss: 1.2409 - val_accuracy: 0.5675 - lr: 1.0000e-04
# Epoch 14/60
# 448/448 [==============================] - ETA: 0s - loss: 1.2742 - accuracy: 0.5617
# Epoch 14: val_loss did not improve from 1.24087
# 448/448 [==============================] - 41s 91ms/step - loss: 1.2742 - accuracy: 0.5617 - val_loss: 1.2488 - val_accuracy: 0.5702 - lr: 1.0000e-04
# Epoch 15/60
# 448/448 [==============================] - ETA: 0s - loss: 1.2376 - accuracy: 0.5728
# Epoch 15: val_loss improved from 1.24087 to 1.21480, saving model to ferNet.h5
# 448/448 [==============================] - 43s 96ms/step - loss: 1.2376 - accuracy: 0.5728 - val_loss: 1.2148 - val_accuracy: 0.5765 - lr: 1.0000e-04
# Epoch 16/60
# 448/448 [==============================] - ETA: 0s - loss: 1.2081 - accuracy: 0.5802
# Epoch 16: val_loss did not improve from 1.21480
# 448/448 [==============================] - 42s 92ms/step - loss: 1.2081 - accuracy: 0.5802 - val_loss: 1.2150 - val_accuracy: 0.5816 - lr: 1.0000e-04
# Epoch 17/60
# 448/448 [==============================] - ETA: 0s - loss: 1.1791 - accuracy: 0.5931
# Epoch 17: val_loss improved from 1.21480 to 1.18539, saving model to ferNet.h5
# 448/448 [==============================] - 43s 96ms/step - loss: 1.1791 - accuracy: 0.5931 - val_loss: 1.1854 - val_accuracy: 0.5968 - lr: 1.0000e-04
# Epoch 18/60
# 448/448 [==============================] - ETA: 0s - loss: 1.1511 - accuracy: 0.5999
# Epoch 18: val_loss improved from 1.18539 to 1.16793, saving model to ferNet.h5
# 448/448 [==============================] - 43s 96ms/step - loss: 1.1511 - accuracy: 0.5999 - val_loss: 1.1679 - val_accuracy: 0.5950 - lr: 1.0000e-04
# Epoch 19/60
# 448/448 [==============================] - ETA: 0s - loss: 1.1190 - accuracy: 0.6163
# Epoch 19: val_loss improved from 1.16793 to 1.14200, saving model to ferNet.h5
# 448/448 [==============================] - 42s 93ms/step - loss: 1.1190 - accuracy: 0.6163 - val_loss: 1.1420 - val_accuracy: 0.6057 - lr: 1.0000e-04
# Epoch 20/60
# 448/448 [==============================] - ETA: 0s - loss: 1.0967 - accuracy: 0.6210
# Epoch 20: val_loss did not improve from 1.14200
# 448/448 [==============================] - 41s 92ms/step - loss: 1.0967 - accuracy: 0.6210 - val_loss: 1.1580 - val_accuracy: 0.6113 - lr: 1.0000e-04
# Epoch 21/60
# 448/448 [==============================] - ETA: 0s - loss: 1.0715 - accuracy: 0.6331
# Epoch 21: val_loss improved from 1.14200 to 1.11288, saving model to ferNet.h5
# 448/448 [==============================] - 43s 95ms/step - loss: 1.0715 - accuracy: 0.6331 - val_loss: 1.1129 - val_accuracy: 0.6184 - lr: 1.0000e-04
# Epoch 22/60
# 448/448 [==============================] - ETA: 0s - loss: 1.0497 - accuracy: 0.6412
# Epoch 22: val_loss improved from 1.11288 to 1.08595, saving model to ferNet.h5
# 448/448 [==============================] - 44s 98ms/step - loss: 1.0497 - accuracy: 0.6412 - val_loss: 1.0859 - val_accuracy: 0.6268 - lr: 1.0000e-04
# Epoch 23/60
# 448/448 [==============================] - ETA: 0s - loss: 1.0248 - accuracy: 0.6477
# Epoch 23: val_loss did not improve from 1.08595
# 448/448 [==============================] - 42s 94ms/step - loss: 1.0248 - accuracy: 0.6477 - val_loss: 1.1296 - val_accuracy: 0.6158 - lr: 1.0000e-04
# Epoch 24/60
# 448/448 [==============================] - ETA: 0s - loss: 1.0093 - accuracy: 0.6574
# Epoch 24: val_loss did not improve from 1.08595
# 448/448 [==============================] - 43s 95ms/step - loss: 1.0093 - accuracy: 0.6574 - val_loss: 1.1180 - val_accuracy: 0.6304 - lr: 1.0000e-04
# Epoch 25/60
# 448/448 [==============================] - ETA: 0s - loss: 0.9785 - accuracy: 0.6681
# Epoch 25: val_loss did not improve from 1.08595
# 448/448 [==============================] - 42s 94ms/step - loss: 0.9785 - accuracy: 0.6681 - val_loss: 1.1097 - val_accuracy: 0.6285 - lr: 1.0000e-04
# Epoch 26/60
# 448/448 [==============================] - ETA: 0s - loss: 0.9637 - accuracy: 0.6744
# Epoch 26: val_loss did not improve from 1.08595
# 448/448 [==============================] - 42s 93ms/step - loss: 0.9637 - accuracy: 0.6744 - val_loss: 1.1064 - val_accuracy: 0.6356 - lr: 1.0000e-04
# Epoch 27/60
# 448/448 [==============================] - ETA: 0s - loss: 0.9468 - accuracy: 0.6791
# Epoch 27: val_loss did not improve from 1.08595
# 448/448 [==============================] - 42s 93ms/step - loss: 0.9468 - accuracy: 0.6791 - val_loss: 1.1498 - val_accuracy: 0.6257 - lr: 1.0000e-04
# Epoch 28/60
# 448/448 [==============================] - ETA: 0s - loss: 0.9280 - accuracy: 0.6875
# Epoch 28: val_loss did not improve from 1.08595
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 448/448 [==============================] - 42s 94ms/step - loss: 0.9280 - accuracy: 0.6875 - val_loss: 1.0912 - val_accuracy: 0.6378 - lr: 1.0000e-04
# Epoch 29/60
# 448/448 [==============================] - ETA: 0s - loss: 0.8596 - accuracy: 0.7167
# Epoch 29: val_loss improved from 1.08595 to 1.07280, saving model to ferNet.h5
# 448/448 [==============================] - 43s 95ms/step - loss: 0.8596 - accuracy: 0.7167 - val_loss: 1.0728 - val_accuracy: 0.6465 - lr: 2.0000e-05
# Epoch 30/60
# 448/448 [==============================] - ETA: 0s - loss: 0.8359 - accuracy: 0.7241
# Epoch 30: val_loss did not improve from 1.07280
# 448/448 [==============================] - 43s 95ms/step - loss: 0.8359 - accuracy: 0.7241 - val_loss: 1.0771 - val_accuracy: 0.6477 - lr: 2.0000e-05
# Epoch 31/60
# 448/448 [==============================] - ETA: 0s - loss: 0.8081 - accuracy: 0.7344
# Epoch 31: val_loss did not improve from 1.07280
# 448/448 [==============================] - 41s 92ms/step - loss: 0.8081 - accuracy: 0.7344 - val_loss: 1.0800 - val_accuracy: 0.6505 - lr: 2.0000e-05
# Epoch 32/60
# 448/448 [==============================] - ETA: 0s - loss: 0.8036 - accuracy: 0.7341
# Epoch 32: val_loss did not improve from 1.07280
# 448/448 [==============================] - 41s 91ms/step - loss: 0.8036 - accuracy: 0.7341 - val_loss: 1.0819 - val_accuracy: 0.6497 - lr: 2.0000e-05
# Epoch 33/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7906 - accuracy: 0.7382
# Epoch 33: val_loss did not improve from 1.07280
# 448/448 [==============================] - 42s 93ms/step - loss: 0.7906 - accuracy: 0.7382 - val_loss: 1.0776 - val_accuracy: 0.6535 - lr: 2.0000e-05
# Epoch 34/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7901 - accuracy: 0.7403
# Epoch 34: val_loss did not improve from 1.07280
# 448/448 [==============================] - 41s 91ms/step - loss: 0.7901 - accuracy: 0.7403 - val_loss: 1.0876 - val_accuracy: 0.6494 - lr: 2.0000e-05
# Epoch 35/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7686 - accuracy: 0.7459
# Epoch 35: val_loss did not improve from 1.07280
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 448/448 [==============================] - 41s 92ms/step - loss: 0.7686 - accuracy: 0.7459 - val_loss: 1.0869 - val_accuracy: 0.6519 - lr: 2.0000e-05
# Epoch 36/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7612 - accuracy: 0.7514
# Epoch 36: val_loss did not improve from 1.07280
# 448/448 [==============================] - 41s 92ms/step - loss: 0.7612 - accuracy: 0.7514 - val_loss: 1.0833 - val_accuracy: 0.6516 - lr: 4.0000e-06
# Epoch 37/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7499 - accuracy: 0.7544
# Epoch 37: val_loss did not improve from 1.07280
# 448/448 [==============================] - 42s 94ms/step - loss: 0.7499 - accuracy: 0.7544 - val_loss: 1.0785 - val_accuracy: 0.6547 - lr: 4.0000e-06
# Epoch 38/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7487 - accuracy: 0.7559
# Epoch 38: val_loss did not improve from 1.07280
# 448/448 [==============================] - 42s 94ms/step - loss: 0.7487 - accuracy: 0.7559 - val_loss: 1.0803 - val_accuracy: 0.6551 - lr: 4.0000e-06
# Epoch 39/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7406 - accuracy: 0.7609
# Epoch 39: val_loss did not improve from 1.07280
# 448/448 [==============================] - 42s 94ms/step - loss: 0.7406 - accuracy: 0.7609 - val_loss: 1.0863 - val_accuracy: 0.6536 - lr: 4.0000e-06
# Epoch 40/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7432 - accuracy: 0.7577
# Epoch 40: val_loss did not improve from 1.07280
# 448/448 [==============================] - 43s 95ms/step - loss: 0.7432 - accuracy: 0.7577 - val_loss: 1.0803 - val_accuracy: 0.6539 - lr: 4.0000e-06
# Epoch 41/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7396 - accuracy: 0.7614
# Epoch 41: val_loss did not improve from 1.07280
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
# 448/448 [==============================] - 42s 94ms/step - loss: 0.7396 - accuracy: 0.7614 - val_loss: 1.0870 - val_accuracy: 0.6542 - lr: 4.0000e-06
# Epoch 42/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7411 - accuracy: 0.7599
# Epoch 42: val_loss did not improve from 1.07280
# 448/448 [==============================] - 41s 92ms/step - loss: 0.7411 - accuracy: 0.7599 - val_loss: 1.0812 - val_accuracy: 0.6547 - lr: 8.0000e-07
# Epoch 43/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7404 - accuracy: 0.7603
# Epoch 43: val_loss did not improve from 1.07280
# 448/448 [==============================] - 40s 89ms/step - loss: 0.7404 - accuracy: 0.7603 - val_loss: 1.0806 - val_accuracy: 0.6558 - lr: 8.0000e-07
# Epoch 44/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7369 - accuracy: 0.7614
# Epoch 44: val_loss did not improve from 1.07280
# 448/448 [==============================] - 42s 93ms/step - loss: 0.7369 - accuracy: 0.7614 - val_loss: 1.0787 - val_accuracy: 0.6554 - lr: 8.0000e-07
# Epoch 45/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7405 - accuracy: 0.7593
# Epoch 45: val_loss did not improve from 1.07280
# 448/448 [==============================] - 42s 93ms/step - loss: 0.7405 - accuracy: 0.7593 - val_loss: 1.0793 - val_accuracy: 0.6571 - lr: 8.0000e-07
# Epoch 46/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7286 - accuracy: 0.7638
# Epoch 46: val_loss did not improve from 1.07280
# 448/448 [==============================] - 42s 93ms/step - loss: 0.7286 - accuracy: 0.7638 - val_loss: 1.0804 - val_accuracy: 0.6564 - lr: 8.0000e-07
# Epoch 47/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7341 - accuracy: 0.7593
# Epoch 47: val_loss did not improve from 1.07280
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1.600000018697756e-07.
# 448/448 [==============================] - 41s 91ms/step - loss: 0.7341 - accuracy: 0.7593 - val_loss: 1.0803 - val_accuracy: 0.6569 - lr: 8.0000e-07
# Epoch 48/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7365 - accuracy: 0.7614
# Epoch 48: val_loss did not improve from 1.07280
# 448/448 [==============================] - 41s 92ms/step - loss: 0.7365 - accuracy: 0.7614 - val_loss: 1.0812 - val_accuracy: 0.6572 - lr: 1.6000e-07
# Epoch 49/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7334 - accuracy: 0.7597
# Epoch 49: val_loss did not improve from 1.07280
# 448/448 [==============================] - 41s 92ms/step - loss: 0.7334 - accuracy: 0.7597 - val_loss: 1.0820 - val_accuracy: 0.6568 - lr: 1.6000e-07
# Epoch 50/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7280 - accuracy: 0.7633
# Epoch 50: val_loss did not improve from 1.07280
# 448/448 [==============================] - 42s 94ms/step - loss: 0.7280 - accuracy: 0.7633 - val_loss: 1.0806 - val_accuracy: 0.6572 - lr: 1.6000e-07
# Epoch 51/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7336 - accuracy: 0.7601
# Epoch 51: val_loss did not improve from 1.07280
# 448/448 [==============================] - 40s 89ms/step - loss: 0.7336 - accuracy: 0.7601 - val_loss: 1.0815 - val_accuracy: 0.6574 - lr: 1.6000e-07
# Epoch 52/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7296 - accuracy: 0.7638
# Epoch 52: val_loss did not improve from 1.07280
# 448/448 [==============================] - 41s 91ms/step - loss: 0.7296 - accuracy: 0.7638 - val_loss: 1.0817 - val_accuracy: 0.6567 - lr: 1.6000e-07
# Epoch 53/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7346 - accuracy: 0.7609
# Epoch 53: val_loss did not improve from 1.07280
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 3.199999980552093e-08.
# 448/448 [==============================] - 38s 85ms/step - loss: 0.7346 - accuracy: 0.7609 - val_loss: 1.0814 - val_accuracy: 0.6565 - lr: 1.6000e-07
# Epoch 54/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7310 - accuracy: 0.7654
# Epoch 54: val_loss did not improve from 1.07280
# 448/448 [==============================] - 41s 91ms/step - loss: 0.7310 - accuracy: 0.7654 - val_loss: 1.0800 - val_accuracy: 0.6565 - lr: 3.2000e-08
# Epoch 55/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7292 - accuracy: 0.7624
# Epoch 55: val_loss did not improve from 1.07280
# 448/448 [==============================] - 43s 95ms/step - loss: 0.7292 - accuracy: 0.7624 - val_loss: 1.0806 - val_accuracy: 0.6567 - lr: 3.2000e-08
# Epoch 56/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7320 - accuracy: 0.7635
# Epoch 56: val_loss did not improve from 1.07280
# 448/448 [==============================] - 43s 95ms/step - loss: 0.7320 - accuracy: 0.7635 - val_loss: 1.0822 - val_accuracy: 0.6567 - lr: 3.2000e-08
# Epoch 57/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7339 - accuracy: 0.7631
# Epoch 57: val_loss did not improve from 1.07280
# 448/448 [==============================] - 42s 93ms/step - loss: 0.7339 - accuracy: 0.7631 - val_loss: 1.0804 - val_accuracy: 0.6565 - lr: 3.2000e-08
# Epoch 58/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7280 - accuracy: 0.7605
# Epoch 58: val_loss did not improve from 1.07280
# 448/448 [==============================] - 45s 99ms/step - loss: 0.7280 - accuracy: 0.7605 - val_loss: 1.0819 - val_accuracy: 0.6562 - lr: 3.2000e-08
# Epoch 59/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7383 - accuracy: 0.7588
# Epoch 59: val_loss did not improve from 1.07280
#
# Epoch 59: ReduceLROnPlateau reducing learning rate to 6.399999818995639e-09.
# 448/448 [==============================] - 44s 97ms/step - loss: 0.7383 - accuracy: 0.7588 - val_loss: 1.0806 - val_accuracy: 0.6567 - lr: 3.2000e-08
# Epoch 60/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7337 - accuracy: 0.7612
# Epoch 60: val_loss did not improve from 1.07280
# 448/448 [==============================] - 39s 88ms/step - loss: 0.7337 - accuracy: 0.7612 - val_loss: 1.0825 - val_accuracy: 0.6567 - lr: 6.4000e-09

# %% [markdown]
# ## Loss and Accuracy plot

# %%
plt.figure(figsize=(14,5))
plt.subplot(1,2,2)
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['train', 'test'], loc='upper left')

plt.subplot(1,2,1)
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# high accracy is achieved on training set but accuracy on validation set is stuck at 66% also no overfitting can se seen in the dataset hence is can be concluded that the inefficiency may be due to the unbalanced dataset

# %% [markdown]
# ### Model evaluation

# %%
train_loss, train_accu = fernet.evaluate(training_set)
test_loss, test_accu = fernet.evaluate(test_set)
print("final train accuracy = {:.2f} , validation accuracy = {:.2f}".format(train_accu*100, test_accu*100))
# Out:
# 449/449 [==============================] - 32s 70ms/step - loss: 0.5772 - accuracy: 0.8336
# 113/113 [==============================] - 5s 42ms/step - loss: 1.0822 - accuracy: 0.6567
# final train accuracy = 83.36 , validation accuracy = 65.67

# %%
fernet.save_weights('fernet_bestweight.h5')

# %% [markdown]
# ### Confusion Matrix and Classification on training set

# %%
y_pred = fernet.predict(training_set)
y_pred = np.argmax(y_pred, axis=1)
class_labels = test_set.class_indices
class_labels = {v:k for k,v in class_labels.items()}

from sklearn.metrics import classification_report, confusion_matrix
cm_train = confusion_matrix(training_set.classes, y_pred)
print('Confusion Matrix')
print(cm_train)
print('Classification Report')
target_names = list(class_labels.values())
print(classification_report(training_set.classes, y_pred, target_names=target_names))

plt.figure(figsize=(8,8))
plt.imshow(cm_train, interpolation='nearest')
plt.colorbar()
tick_mark = np.arange(len(target_names))
_ = plt.xticks(tick_mark, target_names, rotation=90)
_ = plt.yticks(tick_mark, target_names)
# Out:
# 449/449 [==============================] - 36s 79ms/step
# Confusion Matrix
# [[ 564   52  496  999  728  693  463]
#  [  73    3   49  116   84   65   46]
#  [ 559   52  521 1041  755  688  481]
#  [ 907   88  878 1916 1364 1221  841]
#  [ 667   55  643 1269  921  875  535]
#  [ 680   57  590 1287  878  836  502]
#  [ 413   36  397  859  576  561  329]]
# Classification Report
#               precision    recall  f1-score   support
#
#        angry       0.15      0.14      0.14      3995
#      disgust       0.01      0.01      0.01       436
#         fear       0.15      0.13      0.14      4097
#        happy       0.26      0.27      0.26      7215
#      neutral       0.17      0.19      0.18      4965
#          sad       0.17      0.17      0.17      4830
#     surprise       0.10      0.10      0.10      3171
#
#     accuracy                           0.18     28709
#    macro avg       0.14      0.14      0.14     28709
# weighted avg       0.18      0.18      0.18     28709

# %% [markdown]
# ### Confusion Matrix and Classification on test set

# %%
y_pred = fernet.predict(test_set)
y_pred = np.argmax(y_pred, axis=1)
class_labels = test_set.class_indices
class_labels = {v:k for k,v in class_labels.items()}

#from sklearn.metrics import classification_report, confusion_matrix
cm_test = confusion_matrix(test_set.classes, y_pred)
print('Confusion Matrix')
print(cm_test)
print('Classification Report')
target_names = list(class_labels.values())
print(classification_report(test_set.classes, y_pred, target_names=target_names))

plt.figure(figsize=(8,8))
plt.imshow(cm_test, interpolation='nearest')
plt.colorbar()
tick_mark = np.arange(len(target_names))
_ = plt.xticks(tick_mark, target_names, rotation=90)
_ = plt.yticks(tick_mark, target_names)
# Out:
# 113/113 [==============================] - 5s 45ms/step
# Confusion Matrix
# [[144  13 107 236 174 159 125]
#  [ 15   0  17  27  25  18   9]
#  [135   6 108 250 215 179 131]
#  [252  17 207 468 339 295 196]
#  [172   8 128 312 272 214 127]
#  [187  10 129 304 233 224 160]
#  [143  10 102 225 141 119  91]]
# Classification Report
#               precision    recall  f1-score   support
#
#        angry       0.14      0.15      0.14       958
#      disgust       0.00      0.00      0.00       111
#         fear       0.14      0.11      0.12      1024
#        happy       0.26      0.26      0.26      1774
#      neutral       0.19      0.22      0.21      1233
#          sad       0.19      0.18      0.18      1247
#     surprise       0.11      0.11      0.11       831
#
#     accuracy                           0.18      7178
#    macro avg       0.15      0.15      0.15      7178
# weighted avg       0.18      0.18      0.18      7178
